# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/Netflixdb.csv')
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Information about Particular Shows

# %%
data[data['Title'].isin(['Dark'])]
# Out:
#      Show_Id Category Title Director  \
# 1610   s1611  TV Show  Dark      NaN
#
#                                                    Cast  \
# 1610  Louis Hofmann, Oliver Masucci, Jördis Triebel,...
#
#                      Country   Release_Date Rating   Duration  \
# 1610  Germany, United States  June 27, 2020  TV-MA  3 Seasons
#
#                                                    Type  \
# 1610  Crime TV Shows, International TV Shows, TV Dramas
#
#                                             Description
# 1610  A missing child sets four families on a franti...

# %%
data[data['Title'].isin(['Peaky Blinders'])]
# Out:
#      Show_Id Category           Title Director  \
# 4806   s4807  TV Show  Peaky Blinders      NaN
#
#                                                    Cast         Country  \
# 4806  Cillian Murphy, Sam Neill, Helen McCrory, Paul...  United Kingdom
#
#          Release_Date Rating   Duration  \
# 4806  October 4, 2019  TV-MA  5 Seasons
#
#                                                    Type  \
# 4806  British TV Shows, Crime TV Shows, Internationa...
#
#                                             Description
# 4806  A notorious gang in 1919 Birmingham, England, ...

# %%
data[data['Title'].str.contains('Peaky Blinders')]
# Out:
#      Show_Id Category           Title Director  \
# 4806   s4807  TV Show  Peaky Blinders      NaN
#
#                                                    Cast         Country  \
# 4806  Cillian Murphy, Sam Neill, Helen McCrory, Paul...  United Kingdom
#
#          Release_Date Rating   Duration  \
# 4806  October 4, 2019  TV-MA  5 Seasons
#
#                                                    Type  \
# 4806  British TV Shows, Crime TV Shows, Internationa...
#
#                                             Description
# 4806  A notorious gang in 1919 Birmingham, England, ...

# %% [markdown]
# Highest Number of Releases in a particular year

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data['Date'] = pd.to_datetime(data['Release_Date'], format='mixed', errors='coerce')
print(data[data['Date'].isnull()])
# Out:
#      Show_Id Category                                        Title Director  \
# 258     s259  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 549     s550  TV Show              Anthony Bourdain: Parts Unknown      NaN
# 2263   s2264  TV Show                                      Frasier      NaN
# 2288   s2289  TV Show                                      Friends      NaN
# 2555   s2556  TV Show                              Gunslinger Girl      NaN
# 3374   s3375  TV Show                                     Kikoriki      NaN
# 3492   s3493  TV Show                          La Familia P. Luche      NaN
# 3946   s3947  TV Show                                        Maron      NaN
# 5138   s5138  TV Show                                 Red vs. Blue      NaN
# 6066   s6066  TV Show                 The Adventures of Figaro Pho      NaN
#
#                                                    Cast         Country  \
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_x          datetime64[ns]
# Date            datetime64[ns]
# dtype: object

# %%
data['Date'].dt.year.value_counts()
# Out:
# Date
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data['Date'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Note: 2019 has the highest number of releases.

# %% [markdown]
# Total Number of Movies & TV Shows in the Dataset

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data['Year'] = data['Date'].dt.year
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_x       Date  \
# 0  In a future where the elite inhabit an island ... 2020-08-14 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23 2016-12-23
#
#      Year
# 0  2020.0
# 1  2016.0

# %%
data[(data['Category'] == 'Movie') & (data['Year']) == 2000]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_x, Date, Year]
# Index: []

# %%
data[(data['Category'] == 'Movie') & (data['Year']) == 2019]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_x, Date, Year]
# Index: []

# %% [markdown]
# India Releases

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_x       Date  \
# ...

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
data[(data['Category'] == 'Movie') & (data['Country'] == 'India')]['Title']
# Out:
# 8                            706
# 9                           1920
# 18                        15-Aug
# 20          ​​Kuch Bheege Alfaaz
# 21                  ​Goli Soda 2
#                   ...
# 7766                        Zero
# 7771    Zindagi Na Milegi Dobara
# 7778                    Zokkomon
# 7782                         Zoo
# 7785                      Zubaan
# Name: Title, Length: 852, dtype: object

# %% [markdown]
# UK Releases

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'United Kingdom')]['Title']
# Out:
# 58                                      100% Hotter
# 85                                         21 Again
# 258     A Young Doctor's Notebook and Other Stories
# 321                                          Africa
# 324                                      After Life
#                            ...
# 7632                             Win the Wilderness
# 7647                   Witches: A Century of Murder
# 7670                         World War II in Colour
# 7671                         World's Busiest Cities
# 7740                                Young Wallander
# Name: Title, Length: 204, dtype: object

# %%
data[(data['Category'] == 'Movie') & (data['Country'] == 'United Kingdom')]['Title']
# Out:
# 19                                         '89
# 82                         2036 Origin Unknown
# 93                           27: Gone Too Soon
# 181     A Grand Night In: The Story of Aardman
# 196                             A Little Chaos
#                          ...
# 7615                Why Are We Getting So Fat?
# 7628                                  Williams
# 7649                             Without Gorky
# 7688                    XV: Beyond the Tryline
# 7725                              You Can Tutu
# Name: Title, Length: 193, dtype: object

# %% [markdown]
# Top 10 directors with highest number of Shows/Movies given to Netflix

# %%
data['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: count, dtype: int64

# %% [markdown]
# Records on Specific Genre of a particular country
# Test case: Genre- Comedy, Category - Movie, Country - UK

# %%
data[((data['Category'] == 'Movie') &(data['Type'])== 'Comedies')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_x, Date, Year]
# Index: []

# %%
data[((data['Category'] == 'Movie') & (data['Type'] == 'Comedies')) | (data['Country']== 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# Test Case-2: Category- Movie, Genre- Comedies, Country- Germany

# %%
data[((data['Category'] == 'Movie') & (data['Type'] == 'Comedies')) | (data['Country']== 'Germany')]
# Out:
#      Show_Id Category                         Title                Director  \
# 33       s34    Movie                  #realityhigh        Fernando Lebrija
# 72       s73    Movie                      17 Again             Burr Steers
# 84       s85    Movie                     21 & Over  Jon Lucas, Scott Moore
# 102     s103    Movie           3 Türken & ein Baby             Sinan Akkuş
# 148     s149    Movie          A Bad Moms Christmas  Jon Lucas, Scott Moore
# ...      ...      ...                           ...                     ...
# 7503   s7502    Movie  We Are Young. We Are Strong.          Burhan Qurbani
# 7590   s7589    Movie             Where's the Money         Scott Zabielski
# 7623   s7622    Movie                     Wild Oats            Andy Tennant
# 7634   s7633    Movie                  Wine Country             Amy Poehler
# 7664   s7663    Movie                       Work It           Laura Terruso
#
# ...

# %% [markdown]
# A Tom Cruise Cast...

# %%
data[data['Cast'] == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_x, Date, Year]
# Index: []

# %%
data1 = data.dropna()

# %%
data1.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_x       Date  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23 2016-12-23
# 2  When an army recruit is found dead, his fellow... 2018-12-20 2018-12-20
#
#      Year
# 1  2016.0
# 2  2018.0

# %%
data1[data1['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_x       Date  \
# 3860  Through chance, human action, past history and... 2020-01-01 2020-01-01
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01 2019-07-01
#
#         Year
# 3860  2020.0
# 5071  2019.0

# %% [markdown]
# Cillian Murphy Cast

# %%
data1[data1['Cast'].str.contains('Cillian Murphy')]
# Out:
#      Show_Id Category          Title           Director  \
# 2270   s2271    Movie      Free Fire       Ben Wheatley
# 2979   s2980    Movie      Inception  Christopher Nolan
# 7188   s7187    Movie  Transcendence      Wally Pfister
#
#                                                    Cast  \
# 2270  Sharlto Copley, Armie Hammer, Brie Larson, Cil...
# 2979  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# 7188  Johnny Depp, Rebecca Hall, Morgan Freeman, Pau...
#
#                                    Country      Release_Date Rating Duration  \
# 2270                        United Kingdom  October 21, 2019      R   91 min
# 2979         United States, United Kingdom   January 1, 2020  PG-13  148 min
# 7188  United Kingdom, China, United States  November 1, 2018  PG-13  119 min
#
#                                                   Type  \
# 2270  Action & Adventure, Comedies, Independent Movies
# 2979   Action & Adventure, Sci-Fi & Fantasy, Thrillers
# ...

# %% [markdown]
# Ratings

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
data['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# Test Case: Rating- TV14, Country- Canada

# %%
data[(data['Category'] == 'Movie') & (data['Rating']== 'TV-14')].shape
# Out:
# (1272, 14)

# %%
data[(data['Category'] == 'Movie') & (data['Rating']== 'TV-14') & (data['Country'] == 'Canada')].shape
# Out:
# (11, 14)

# %% [markdown]
# Test Case: Rating- R, Year- 2018, Category - TV Shows

# %%
data[((data['Category'] == 'TV Show') & (data['Rating'] == 'R')) | (data['Year']== 2018)]
# Out:
#      Show_Id Category                     Title          Director  \
# 2         s3    Movie                     23:59      Gilbert Chan
# 11       s12  TV Show                      1983               NaN
# 17       s18    Movie                    22-Jul   Paul Greengrass
# 19       s20    Movie                       '89               NaN
# 20       s21    Movie      ​​Kuch Bheege Alfaaz              Onir
# ...      ...      ...                       ...               ...
# 7765   s7764    Movie                     Zenda    Avadhoot Gupte
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay     Anjum Shahzad
# 7773   s7772    Movie                      Zion        Floyd Russ
# 7778   s7777    Movie                  Zokkomon  Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo      Shlok Sharma
#
#                                                    Cast  \
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 11    Robert Więckiewicz, Maciej Musiał, Michalina O...
# ...

# %%
data[((data['Category'] == 'TV Show') & (data['Rating'] == 'R')) | (data['Year'] > 2018)]
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 7         s8    Movie                                      187
# 8         s9    Movie                                      706
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#              Director                                               Cast  \
# 0                 NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# Maximum Duration in TV/Movies

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data[['Minutes', 'Unit']] = data['Duration'].str.split(' ', n=1, expand=True)
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_x       Date  \
# 0  In a future where the elite inhabit an island ... 2020-08-14 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23 2016-12-23
#
#      Year Minutes     Unit
# 0  2020.0       4  Seasons
# 1  2016.0      93      min

# %%
data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].min()
# Out:
# '1'

# %% [markdown]
# Country with highest number of TV Shows

# %%
data_tv = data[data['Category']== 'TV Show']
data_tv.head()
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 5       s6  TV Show      46           Serdar Akar
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 16     s17  TV Show  Feb-09                   NaN
#
#                                                  Cast                Country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...                 Brazil
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...                 Turkey
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...  Poland, United States
# 12                                                NaN                 Mexico
# 16  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...                    NaN
#
#          Release_Date Rating   Duration  \
# 0     August 14, 2020  TV-MA  4 Seasons
# 5        July 1, 2017  TV-MA   1 Season
# 11  November 30, 2018  TV-MA   1 Season
# ...

# %%
data_tv.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %% [markdown]
# Yearwise Sort

# %%
data.sort_values(by = 'Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
data.sort_values(by = 'Year', ascending = False)
# Out:
#      Show_Id Category                         Title  \
# 7353   s7352    Movie                       Unknown
# 2013   s2014    Movie              Enter the Dragon
# 2349   s2350    Movie                     Gangaajal
# 1497   s1498    Movie                Cool Hand Luke
# 1194   s1195    Movie             Can't Hardly Wait
# ...      ...      ...                           ...
# 3374   s3375  TV Show                      Kikoriki
# 3492   s3493  TV Show           La Familia P. Luche
# 3946   s3947  TV Show                         Maron
# 5138   s5138  TV Show                  Red vs. Blue
# 6066   s6066  TV Show  The Adventures of Figaro Pho
#
#                           Director  \
# 7353            Jaume Collet-Serra
# 2013                 Robert Clouse
# 2349                   Prakash Jha
# 1497              Stuart Rosenberg
# 1194  Harry Elfont, Deborah Kaplan
# ...                            ...
# 3374                           NaN
# 3492                           NaN
# ...

# %% [markdown]
# Category - Movie, Type- Drama
# Category - TV Show, Type - Kids TV

# %%
data[((data['Category'] == 'Movie') &(data['Type'])== 'Drama')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_x, Date, Year, Minutes, Unit]
# Index: []

# %%
data[((data['Category'] == 'TV Show') &(data['Type'])== 'Kids TV')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_x, Date, Year, Minutes, Unit]
# Index: []
